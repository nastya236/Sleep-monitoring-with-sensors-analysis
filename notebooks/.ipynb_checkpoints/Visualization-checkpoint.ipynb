# %%
from wonambi import Dataset
import matplotlib.pyplot as plt
import numpy as np
from scipy import fft
import pandas as pd
import scipy
import sys
sys.path.append('..')
from neursa import preprocessing

# %%
d = Dataset('/Users/anastasiafilippova/Downloads/Recording721001/Courbes 002.edf')
path = '/Users/anastasiafilippova/Downloads/Recording721001/Courbes_scores_002.csv'
index = 721002

# %%
data = d.read_data()

# %%
labels = preprocessing.get_labels(path)
info = preprocessing.parse_table_info()

# %%
date = info.loc[index, 'date']

# %%
time = preprocessing.get_time_for_labels(path, date)
time_sensors = preprocessing.get_time_sensors(data)

# %%
plt.psd(data.data[0][9, 100:30*25682], 500)
# Out:
# (array([5.36573300e+08, 3.55622837e+08, 1.12915853e+07, 8.47210663e+05,
#         5.50564710e+04, 4.43999123e+04, 3.95388536e+04, 7.56652424e+03,
#         8.83901458e+03, 1.00325301e+04, 3.66008663e+03, 3.26851383e+03,
#         1.51846765e+03, 1.25870898e+03, 1.98180848e+03, 1.71454311e+03,
#         9.78618879e+02, 5.88937464e+02, 5.25876284e+02, 5.19564509e+02,
#         5.62599944e+02, 5.94845590e+02, 4.97962610e+02, 1.71115397e+02,
#         2.12473956e+02, 1.77948325e+02, 2.38452600e+02, 2.31558902e+02,
#         1.75381729e+02, 1.38952375e+02, 1.34882294e+02, 1.60000185e+02,
#         1.40320052e+02, 1.11846051e+02, 5.95943151e+01, 6.36032683e+01,
#         7.11619530e+01, 1.41387872e+02, 9.83909338e+01, 8.26220160e+01,
#         1.02255879e+02, 6.28609889e+01, 4.98416857e+01, 8.19427188e+01,
#         9.21872122e+01, 5.13273208e+01, 8.30751034e+01, 9.29105530e+01,
#         1.04731362e+02, 1.03423802e+02, 1.20320810e+02, 9.21256466e+01,
# ...

# %%
plt.figure(figsize=(15,10))
start = 400
stop = 4500
chan = 9
start_sensors = int(time_sensors.shape[0]*(start/time.shape[0]))
stop_sensors = int(time_sensors.shape[0]*(stop/time.shape[0]))
plt.plot(time[start:stop], labels[start:stop]*1000)
plt.plot(time_sensors[start_sensors:stop_sensors], data.data[0][chan][start_sensors:stop_sensors])
